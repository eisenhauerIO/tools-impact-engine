# %%
import pandas as pd

# %%
df = pd.read_csv("impact_analysis_result.csv")

# %%
df.sort_values(["product_id", "date"])
# Out:
#      product_id        name      category   price        date  sales_volume  \
# 0      PROD0001     T-Shirt      Clothing  152.19  2024-11-01             1
# 50     PROD0001     T-Shirt      Clothing  152.19  2024-11-02             3
# 100    PROD0001     T-Shirt      Clothing  152.19  2024-11-03             1
# 150    PROD0001     T-Shirt      Clothing  152.19  2024-11-04             0
# 200    PROD0001     T-Shirt      Clothing  152.19  2024-11-05             0
# ...         ...         ...           ...     ...         ...           ...
# 1299   PROD0050  Remote Car  Toys & Games   90.97  2024-11-26             1
# 1349   PROD0050  Remote Car  Toys & Games   90.97  2024-11-27             4
# 1399   PROD0050  Remote Car  Toys & Games   90.97  2024-11-28             0
# 1449   PROD0050  Remote Car  Toys & Games   90.97  2024-11-29             0
# 1499   PROD0050  Remote Car  Toys & Games   90.97  2024-11-30             3
#
# ...
